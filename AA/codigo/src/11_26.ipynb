# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
fs = './data/imdbFull.p'
DATASET = np.load(fs, allow_pickle=True)

docs = DATASET['data']
y = DATASET['target']

# %%
tfidf = TfidfVectorizer().fit(docs)

# %%
voc = tfidf.get_feature_names_out()
